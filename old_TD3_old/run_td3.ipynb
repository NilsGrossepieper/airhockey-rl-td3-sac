# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys

# Change directory to your RL project in Google Drive
PROJECT_DIR = '/content/drive/MyDrive/rl-hockey-homework/TD3'  # Adjust if needed
os.chdir(PROJECT_DIR)
sys.path.append(PROJECT_DIR)  # Ensure correct import paths

# %%
# !pip install -q gymnasium wandb torch numpy
# !apt-get install -y python3-dev python3-pip swig > /dev/null 2>&1
# !pip uninstall -y box2d box2d-kengz box2d-py > /dev/null 2>&1
# !pip install -q gymnasium[box2d] swig box2d-kengz
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.4/425.4 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 32.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 76.6 MB/s eta 0:00:00
# ...

# %%
import time
import Box2D
import numpy as np
import torch
from train_td3_dynamic import train_td3_dynamic  # Import training script
# Out:
# Using device: cuda

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Mon Feb 17 13:21:30 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 13.6 gigabytes of available RAM
#
# Not using a high-RAM runtime

# %%
# Start the timer
start_time = time.time()

train_td3_dynamic(
    num_episodes=3000,  # Change this to a higher number for real training
    save_every=100,
    render=False,  # Set to False since rendering doesn't work in Colab
    load_existing_agent=None,  # Set model filename if resuming training
    experiment_name="colab_run_2",  # Name experiment for tracking
    seed=42  # Set seed for reproducibility
)

# End the timer
end_time = time.time()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: nils-grossepieper (nils-grossepieper-eberhard-karls-universit-t-t-bingen) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# Tracking run with wandb version 0.19.6
# ...

# %%
# Calculate elapsed time
elapsed_time = end_time - start_time
print(f"\n⏳ Training took {elapsed_time:.2f} seconds (~{elapsed_time/60:.2f} minutes).")
